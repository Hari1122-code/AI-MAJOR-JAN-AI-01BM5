jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.amcarguide.com/wp-content/gallery/trans/bumblebee-camaro-transformers-movie-03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.pinimg.com/736x/48/74/b1/4874b17e583bbee0db9d6e5761095b98--saris-transformers.jpg
# [%] File Downloaded !
#
# ...

# %%
#preprocessing of Data
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['jack sparrow from pirates of the caribbean','tony stark in iron man','spider man in avengers','bumblebee in transformers']

for category in CATEGORIES:
  class_num = CATEGORIES.index(category)
  path = os.path.join(DATADIR,category)
  for img in os.listdir(path):
    img_array = imread(os.path.join(path,img))
    img_resized = resize(img_array,(150,150,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)
    target.append(class_num)

flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(images,target,test_size=0.25,random_state=199)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (60, 150, 150, 3)
# (20, 150, 150, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(x_train[0])
plt.show()
print(CATEGORIES[y_train[0]])
# Out:
# jack sparrow from pirates of the caribbean

# %%
#transfer learning model
from tensorflow import keras
from keras.applications.inception_v3 import InceptionV3

# %%
base_model = InceptionV3(input_shape=(150,150,3),weights='imagenet', include_top=False)
base_model.summary()
# Out:
# ...
# 87916544/87910968 [==============================] - 1s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 32)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 74, 74, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import layers
import tensorflow as tf


x = layers.Flatten()(base_model.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.models.Model(base_model.input, x)

model.compile(optimizer = RMSprop(lr=0.0001), loss = 'binary_crossentropy', metrics = ['acc'])

# %%
history = model.fit(x_train,y_train,epochs = 10,validation_split=0.2)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 9s 3s/step - loss: -6.2354 - acc: 0.2257 - val_loss: -73.7963 - val_acc: 0.1667
# Epoch 2/10
# 2/2 [==============================] - 3s 1s/step - loss: -69.2698 - acc: 0.2535 - val_loss: -126.4672 - val_acc: 0.1667
# Epoch 3/10
# 2/2 [==============================] - 3s 1s/step - loss: -93.8455 - acc: 0.2847 - val_loss: -174.3012 - val_acc: 0.1667
# Epoch 4/10
# 2/2 [==============================] - 3s 1s/step - loss: -163.6756 - acc: 0.2535 - val_loss: -205.9365 - val_acc: 0.1667
# Epoch 5/10
# 2/2 [==============================] - 3s 1s/step - loss: -187.3799 - acc: 0.2743 - val_loss: -239.5379 - val_acc: 0.1667
# Epoch 6/10
# 2/2 [==============================] - 3s 1s/step - loss: -215.8221 - acc: 0.2847 - val_loss: -272.0877 - val_acc: 0.1667
# Epoch 7/10
# 2/2 [==============================] - 3s 1s/step - loss: -218.4631 - acc: 0.2847 - val_loss: -309.6535 - val_acc: 0.1667
# Epoch 8/10
# ...

# %%
model.save("Saved-model-InceptionV3.h5")
